# %% [markdown]
# <a href="https://colab.research.google.com/github/YonatanBur/DataScience/blob/main/%D7%99%D7%95%D7%A0%D7%AA%D7%9F_%D7%91%D7%95%D7%A8%D7%A9%D7%98%D7%99%D7%99%D7%9F_Pandas_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# בתרגיל זה, נשתמש ב dataset בנושא heart failure prediction, כלומר חיזוי מחלות לב
#
# הכנסו לחשבון ה Kaggle שלכם, וחפשו heart failure prediction
#
# תקבלו לא לא מעט תוצאות, רובם כנראה משתמשים באותו dataset, אבל אנשים שונים העלו אותו ל Kaggle עם קוד שהם כתבו כדי לנתח אותו

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# אנחנו נשתמש בקובץ שנמצא ב
#
# https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction
#
#
# הכנסו לקישור, וכיתבו בתיבה מתחת:
#
# 1. כמה features יש?
# 2. ביחרו 2 features, וכיתבו מה משמעותם
# 2. מה משמעות ה target? איזה ערכים הוא יכול לקבל?

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# 1.
# 12
#
# 2.
# age:  גיל הנבדקים
#
# ב. Chol: רמת הכולסטרול
#
# 3.
# HeartDisease הטרגט הוא:
# הוא יכול לקבל 1, 0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# כיתבו פה...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# #חלק א

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# יבאו את ספריית פנדס

# %%
import pandas as pd

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# כעת, יבאו את הקובץ ל Drive שלכם, והכניסו את תוכן ה dataset לתוך משתנה בשם df

# %%
df = pd.read_csv("/content/drive/MyDrive/Data/heart.csv")
#לא עובד לי הדרייב זה עושה ארור
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-72-646319b3ec85> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/drive/MyDrive/Data/heart.csv")
#       2 #לא עובד לי הדרייב זה עושה ארור
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הציגו את התוכן של df

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Chol  FastingBS RestingECG  MaxHR  \
# 0     40   M           ATA        140   289          0     Normal    172
# 1     49   F           NAP        160   180          0     Normal    156
# 2     37   M           ATA        130   283          0         ST     98
# 3     48   F           ASY        138   214          0     Normal    108
# 4     54   M           NAP        150   195          0     Normal    122
# ..   ...  ..           ...        ...   ...        ...        ...    ...
# 913   45   M            TA        110   264          0     Normal    132
# 914   68   M           ASY        144   193          1     Normal    141
# 915   57   M           ASY        130   131          0     Normal    115
# 916   57   F           ATA        130   236          0        LVH    174
# 917   38   M           NAP        138   175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
#
# כעת, יבאו את הקובץ ל GitHub שלכם, והכניסו את תוכן ה dataset לתוך משתנה בשם df

# %%
df = pd.read_csv("https://raw.githubusercontent.com/YonatanBur/DataScience/main/heart%5B1%5D.csv")

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הציגו את התוכן של df

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הערה - אתם אמורים לראות בדיוק את אותו הדבר. בד"כ נשתמש רק באחת השיטות הנ"ל. המטרה כאן היא לתרגל

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
#
# ודאו שהמשתנה שלכם הוא אכן מטיפוס DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <div dir=rtl>
# בידקו וכיתבו בתיבה מתחת:
#
# 1. כמה features מספריים יש?
# 2. וכמה לא מספריים (טקסט)?
# 3. האם יש שורות עם מידע חסר?
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# 1. 7
# 2. 5
# 3. לא

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הדפיסו את 7 השורות הראשונות

# %%
df.head(8)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הדפיסו את 7 השורות האחרונות (בלי לבדוק כמה שורות יש)

# %%
df.tail(8)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 910   41   M           ATA        120          157          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 910    182              N      0.0       Up             0
# 911     90              N      1.0     Flat             1
# 912    123              Y      0.2     Flat             1
# 913    132              N      1.2     Flat             1
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הדפיסו 5 שורות אקראיות

# %%
df.sample(5)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 358   38   M           NAP        115            0          0     Normal
# 456   61   M           NAP        120            0          0     Normal
# 607   53   M           ASY        144          300          1         ST
# 813   69   F            TA        140          239          0     Normal
# 739   54   M           NAP        125          273          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 358    128              Y      0.0     Flat             1
# 456     80              Y      0.0     Flat             1
# 607    128              Y      1.5     Flat             1
# 813    151              N      1.8       Up             0
# 739    152              N      0.5     Down             0

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הדפיסו את שורות 10-14

# %%
df[10:15]
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 10   37   F           NAP        130          211          0     Normal
# 11   58   M           ATA        136          164          0         ST
# 12   39   M           ATA        120          204          0     Normal
# 13   49   M           ASY        140          234          0     Normal
# 14   42   F           NAP        115          211          0         ST
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 10    142              N      0.0       Up             0
# 11     99              Y      2.0     Flat             1
# 12    145              N      0.0       Up             0
# 13    140              Y      1.0     Flat             1
# 14    137              N      0.0       Up             0

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# #חלק ב

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הכניסו את הטור Age לתוך משתנה בשם age
#
# ואז הציגו משתנה זה

# %%
age = df['Age']
age
# Out:
# 0      40
# 1      49
# 2      37
# 3      48
# 4      54
#        ..
# 913    45
# 914    68
# 915    57
# 916    57
# 917    38
# Name: Age, Length: 918, dtype: int64

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# בידקו מהו טיפוס המשתנה של age. אם רוצים שהוא יהיה מטיפוס DataFrame, מה אפשר לעשות?

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
age = df[['Age']]
type(age)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הכניסו את הטורים ChestPainType ו MaxHR למשתנה חדש, והציגו את 12 השורות הראשונות שלו

# %%
maxchest = df[['ChestPainType', 'MaxHR']]

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# בידקו את הטיפוס של משתנה זה. האם הוא יכול להיות מטיפוס Pandas Series או שהוא חייב להיות Pandas DataFrame?

# %%
type(maxchest)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הוסיפו טור חדש, ששמו New Age (עם רווח), שיהיה שווה לטור age אבל הערכים גדולים פי 2

# %%
df['New Age']=age*2
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  New Age
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# בידקו את df, האם קיבלתם את מה שציפיתם?

# %%
df
#כן
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  New Age
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# כעת, מיחקו את הטור שהוספתם, אבל רק לצורך תצוגה, כלומר הטור לא באמת ימחק

# %%
df.drop('New Age', axis=1)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# ודאי שהטור החדש עדיין קיים

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  New Age
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# עכשיו מיחקו את הטור כך ש df יתעדכן, וודאו זאת
#
# איזה עוד שיטה יש, חוץ מזו שבחרתם? האם אתם מבינים אותה?

# %%
df.drop('New Age', axis=1, inplace=True)
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# אם בשלב הזה הייתם רוצים לקבל בחזרה את הטור New Age שמחקתם, מה הייתם צריכים לעשות (בלי לכתוב מחדש קוד)?

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# משנה לfalse ?

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# #חלק ג

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# בלי לחפש ידנית בטבלה, בידקו - מהו הגיל הצעיר ביותר מבין הנבדקים?

# %%
df['Age'].min()
# Out:
# 28

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
#
# בלי לחפש ידנית בטבלה, בידקו - מהו ערך הכולסטרול הגבוה ביותר מבין הנבדקים?

# %%
df['Cholesterol'].max()
# Out:
# 603

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# האם הטבלה שלכם השתנתה עקב הפעולה שעשיתם?
#
# בצעו שוב את פעולת המיון, אך הפעם כך שהטבלה תהיה מסודרת לפי סדר ערכי הכולסטרול, מהגבוה לנמוך

# %%
df = df.sort_values('Cholesterol' , ascending = False) #סדר הפוך
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
# 76    32   M           ASY        118          529          0     Normal
# 30    53   M           NAP        145          518          0     Normal
# 250   44   M           ASY        135          491          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 394   57   M           ASY        160            0          1     Normal
# 393   38   M           ASY        150            0          1     Normal
# 392   61   M           ASY        130            0          0        LVH
# 391   70   M           ASY        115            0          0         ST
# 459   41   M           ASY        104            0          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# ודאו שהטבלה מסודרת לפי הסדר הנדרש

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
# 76    32   M           ASY        118          529          0     Normal
# 30    53   M           NAP        145          518          0     Normal
# 250   44   M           ASY        135          491          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 394   57   M           ASY        160            0          1     Normal
# 393   38   M           ASY        150            0          1     Normal
# 392   61   M           ASY        130            0          0        LVH
# 391   70   M           ASY        115            0          0         ST
# 459   41   M           ASY        104            0          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הציגו רק את השורה שבה יש את בעל הכולסטרול הגבוה ביותר

# %%
df.head(1)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 149   54   M           ASY        130          603          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 149    125              Y      1.0     Flat             1

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הציגו את הטבלה המקורית. השתמשו ב sort_index. איך עובד הקסם?

# %%
df = df.sort_index()
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# #חלק ד

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# מהם הערכים השונים שיש ל לטור ST_Slope?

# %%
flat / up
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-1a5f5971f8d2> in <cell line: 1>()
# ----> 1 flat / up
#
# NameError: name 'flat' is not defined

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# כתבו את הקוד הבא (הזכרו קצת בפייתון) - אם כמות הערכים שיש ל ChestPainType גדולה מ-2, הדפיסו good, אחרת הדפיסו bad

# %%
if len(df['ChestPainType']) > 2:
    print("good")
else:
    print("bad")
# Out:
# good

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# מהו ה Feature שיש לו הכי הרבה ערכים שונים?

# %%
df.nunique()
#התשובה היא קולסטרול
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# הציגו את כמות הערכים השונים שיש ל Features השונים בצורה ממוינת, כך שהכמות הקטנה ביותר תופיע למעלה

# %%
df2 = df.nunique()
df2.sort_values()
# Out:
# Sex                 2
# FastingBS           2
# ExerciseAngina      2
# HeartDisease        2
# RestingECG          3
# ST_Slope            3
# ChestPainType       4
# Age                50
# Oldpeak            53
# RestingBP          67
# MaxHR             119
# Cholesterol       222
# dtype: int64

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
# מהו הגיל הממוצע של הנבדקים?

# %%
df['Age'].mean()
#53
# Out:
# 53.510893246187365

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# ומהו החציון של הגיל?

# %%
df['Age'].median()
#54
# Out:
# 54.0

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# האם אפשר לחשב את הממוצע / חציון של הטור ChestPainType? מדוע?

# %%
#כן הוא גם ממוצע מספרים

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# מה הממוצע של טור ה Target? האם יש בטבלה יותר חולים או בריאים?

# %%
df['HeartDisease'].mean()

if df['HeartDisease'].mean() >= 0.5:
    result = "sick"
else:
    result = "healthy"

print(result)

#יותר חולים
# Out:
# sick

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# כמה חולים יש בטבלה? כמה בריאים?

# %%
sick = len(df[df['HeartDisease'] == 1])
healthy = len(df[df['HeartDisease'] == 0])
print(sick)
print(healthy)
# Out:
# 508
# 410

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# #חלק ה - לימוד עצמי
#
# בחלק זה, אתם מתבקשים ללמוד פונקציות Pandas בעצמכם, ע"י שימוש בחיפוש ברשת, ChatGPT וכדומה

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# ב df, שנו את שם הטור Cholesterol ל Chol.
#
# ודאו שהשינוי בוצע

# %%
df = df.rename(columns={'Cholesterol': 'Chol'})

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Chol  FastingBS RestingECG  MaxHR  \
# 0     40   M           ATA        140   289          0     Normal    172
# 1     49   F           NAP        160   180          0     Normal    156
# 2     37   M           ATA        130   283          0         ST     98
# 3     48   F           ASY        138   214          0     Normal    108
# 4     54   M           NAP        150   195          0     Normal    122
# ..   ...  ..           ...        ...   ...        ...        ...    ...
# 913   45   M            TA        110   264          0     Normal    132
# 914   68   M           ASY        144   193          1     Normal    141
# 915   57   M           ASY        130   131          0     Normal    115
# 916   57   F           ATA        130   236          0        LVH    174
# 917   38   M           NAP        138   175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# בלי למיין, הציגו את הגיל הגבוה ביותר (רמז - דומה לפונקציות הממוצע)

# %%
df['Age'].max()
# Out:
# 77

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# #חלק ו
#
# עבודה עצמית - חפשו ב Kaggle שני סוגים של datasets:
#
# 1. מתאים לקלאסיפיקציה (כמו הדאטהסט שעליו עבדתם פה). הסבירו בקצרה מהו ה target / label
#
# 2. מתאים לרגרסיה - הסבירו מהו ה target / label

# %% [markdown]
# <div dir="rtl" lang="he" xml:lang="he">
#
# (שימו פה את הקישורים וההסברים)

# %%
hs = pd.read_csv("https://raw.githubusercontent.com/YonatanBur/DataScience/main/all_seasons%5B1%5D.csv")
hs.info()
#1. Target / Label  "Drafted לנחש האם השחקן  דרפטאט או לא לפי המידע עליו
#2. Target/Label: "Points per Game (pts)"  לחזות את הנקודות שלו לפי היכולות שלו
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         12844 non-null  int64
#  1   player_name        12844 non-null  object
#  2   team_abbreviation  12844 non-null  object
#  3   age                12844 non-null  float64
#  4   player_height      12844 non-null  float64
#  5   player_weight      12844 non-null  float64
#  6   college            12844 non-null  object
#  7   country            12844 non-null  object
#  8   draft_year         12844 non-null  object
#  9   draft_round        12844 non-null  object
#  10  draft_number       12844 non-null  object
#  11  gp                 12844 non-null  int64
#  12  pts                12844 non-null  float64
#  13  reb                12844 non-null  float64
#  14  ast                12844 non-null  float64
#  15  net_rating         12844 non-null  float64
# ...
